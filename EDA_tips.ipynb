# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %matplotlib inline

# %%
df = sns.load_dataset('tips')

# %%
df.shape
# Out:
# (244, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.drop_duplicates(inplace = True)

# %%
sns.histplot(x = "total_bill", data = df)
plt.axvline(x=np.mean(df['total_bill']), color='r', linestyle='--')

# %%
sns.histplot(x = "tip", data = df)
plt.axvline(x=np.mean(df['tip']), color='r', linestyle='--')

# %%
sns.countplot(x = "sex", data = df)
plt.xlabel("Sex")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.countplot(x = "smoker", data = df)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x = "day", data = df)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x = "time", data = df)
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
sns.countplot(x = "size", data = df)
# Out:
# <Axes: xlabel='size', ylabel='count'>

# %%
sns.scatterplot(x = "tip",
                y = "total_bill",
                hue = "size",
                data = df)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.boxplot(x = "sex", y = "tip", data = df)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x = "sex", y = "total_bill", data = df)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(x = "smoker", y = "tip", data = df)
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>

# %%
sns.boxplot(x = "smoker", y = "total_bill", data = df)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
df.groupby(['day', 'time'])['total_bill'].mean().sort_values(ascending = False).plot(kind = 'bar')
plt.xlabel("Day/Time")
plt.ylabel("Total Bill")
# Out:
# /tmp/ipython-input-1287682832.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['day', 'time'])['total_bill'].mean().sort_values(ascending = False).plot(kind = 'bar')
# Text(0, 0.5, 'Total Bill')

# %%
grid = sns.FacetGrid(tips, col='day', row='time')
grid.map(sns.boxplot,'total_bill')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:718: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
sns.heatmap(df[['tip', 'total_bill','size']].corr(),
            cmap = "coolwarm",
            annot = True)
# Out:
# <Axes: >
